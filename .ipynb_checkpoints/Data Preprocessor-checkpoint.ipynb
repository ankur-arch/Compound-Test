# %%
# %load_ext nb_black
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %%
import torch
import torchvision as tv
import os

# %%
TRAIN_DIR = os.path.join(os.getcwd(), "dataset\\CMATERdbTrain")

# %%
TEST_DIR = os.path.join(os.getcwd(), "dataset\\CMATERdbTest")

# %%
import skimage.io as sk

# %%
sk.imshow(sk.imread(os.path.join(TRAIN_DIR, "1\\bcc000000.bmp")))

# %%
os.getcwd()
# Out:
# 'F:\\Research\\Week 4'

# %%
for root, dirs_list, files_list in os.walk(TRAIN_DIR):
    print(root)
print(files_list)
# Out:
# F:\Research\Week 4\dataset\CMATERdbTrain
# F:\Research\Week 4\dataset\CMATERdbTrain\1
# F:\Research\Week 4\dataset\CMATERdbTrain\100
# F:\Research\Week 4\dataset\CMATERdbTrain\103
# F:\Research\Week 4\dataset\CMATERdbTrain\103\2
# F:\Research\Week 4\dataset\CMATERdbTrain\11
# F:\Research\Week 4\dataset\CMATERdbTrain\112
# F:\Research\Week 4\dataset\CMATERdbTrain\112\1
# F:\Research\Week 4\dataset\CMATERdbTrain\112\2
# F:\Research\Week 4\dataset\CMATERdbTrain\113
# F:\Research\Week 4\dataset\CMATERdbTrain\116
# F:\Research\Week 4\dataset\CMATERdbTrain\119
# F:\Research\Week 4\dataset\CMATERdbTrain\12
# F:\Research\Week 4\dataset\CMATERdbTrain\12\1
# F:\Research\Week 4\dataset\CMATERdbTrain\12\2
# F:\Research\Week 4\dataset\CMATERdbTrain\123
# F:\Research\Week 4\dataset\CMATERdbTrain\125
# F:\Research\Week 4\dataset\CMATERdbTrain\126
# F:\Research\Week 4\dataset\CMATERdbTrain\13
# F:\Research\Week 4\dataset\CMATERdbTrain\139
# F:\Research\Week 4\dataset\CMATERdbTrain\14
# ...

# %%
for root, dirs_list, files_list in os.walk(TEST_DIR):
    print(root)
print(files_list)
# Out:
# F:\Research\Week 4\dataset\CMATERdbTest
# F:\Research\Week 4\dataset\CMATERdbTest\1
# F:\Research\Week 4\dataset\CMATERdbTest\100
# F:\Research\Week 4\dataset\CMATERdbTest\101
# F:\Research\Week 4\dataset\CMATERdbTest\103
# F:\Research\Week 4\dataset\CMATERdbTest\103\2
# F:\Research\Week 4\dataset\CMATERdbTest\105
# F:\Research\Week 4\dataset\CMATERdbTest\109
# F:\Research\Week 4\dataset\CMATERdbTest\11
# F:\Research\Week 4\dataset\CMATERdbTest\112
# F:\Research\Week 4\dataset\CMATERdbTest\112\1
# F:\Research\Week 4\dataset\CMATERdbTest\112\2
# F:\Research\Week 4\dataset\CMATERdbTest\113
# F:\Research\Week 4\dataset\CMATERdbTest\115
# F:\Research\Week 4\dataset\CMATERdbTest\116
# F:\Research\Week 4\dataset\CMATERdbTest\119
# F:\Research\Week 4\dataset\CMATERdbTest\12
# F:\Research\Week 4\dataset\CMATERdbTest\12\1
# F:\Research\Week 4\dataset\CMATERdbTest\12\2
# F:\Research\Week 4\dataset\CMATERdbTest\123
# F:\Research\Week 4\dataset\CMATERdbTest\125
# ...

# %%
class CompoundCharacterDataset(torch.utils.data.Dataset):
    def __init__(self):
        self.df = df
        self.transform = transform
        self.loader = loader

# %%
for root, dirs, files in os.walk("dataset\IsolatedTrain", topdown=False):
    for name in files:
        print(os.path.join(root, name))
# Out:
# dataset\IsolatedTrain\1\bcc000000.bmp
# dataset\IsolatedTrain\1\bcc000001.bmp
# dataset\IsolatedTrain\1\bcc000002.bmp
# dataset\IsolatedTrain\1\bcc000003.bmp
# dataset\IsolatedTrain\1\bcc000004.bmp
# dataset\IsolatedTrain\1\bcc000005.bmp
# dataset\IsolatedTrain\1\bcc000006.bmp
# dataset\IsolatedTrain\1\bcc000007.bmp
# dataset\IsolatedTrain\1\bcc000008.bmp
# dataset\IsolatedTrain\1\bcc000009.bmp
# dataset\IsolatedTrain\1\bcc000010.bmp
# dataset\IsolatedTrain\1\bcc000011.bmp
# dataset\IsolatedTrain\1\bcc000012.bmp
# dataset\IsolatedTrain\1\bcc000013.bmp
# dataset\IsolatedTrain\1\bcc000014.bmp
# dataset\IsolatedTrain\1\bcc000015.bmp
# dataset\IsolatedTrain\1\bcc000016.bmp
# dataset\IsolatedTrain\1\bcc000017.bmp
# dataset\IsolatedTrain\1\bcc000018.bmp
# dataset\IsolatedTrain\1\bcc000019.bmp
# dataset\IsolatedTrain\1\bcc000020.bmp
# dataset\IsolatedTrain\1\bcc000021.bmp
# dataset\IsolatedTrain\1\bcc000022.bmp
# dataset\IsolatedTrain\1\bcc000023.bmp
# dataset\IsolatedTrain\1\bcc000024.bmp
# ...

# %%
for root, dirs, files in os.walk("dataset\IsolatedTrain", topdown=False):
    x = root.split("\\")
    print(x)
# Out:
# dataset\IsolatedTrain\1
# dataset\IsolatedTrain\10
# dataset\IsolatedTrain\100
# dataset\IsolatedTrain\101
# dataset\IsolatedTrain\102
# dataset\IsolatedTrain\103\1
# dataset\IsolatedTrain\103\2
# dataset\IsolatedTrain\103
# dataset\IsolatedTrain\104
# dataset\IsolatedTrain\105
# dataset\IsolatedTrain\106
# dataset\IsolatedTrain\107
# dataset\IsolatedTrain\108
# dataset\IsolatedTrain\109
# dataset\IsolatedTrain\11
# dataset\IsolatedTrain\110
# dataset\IsolatedTrain\111
# dataset\IsolatedTrain\112\1
# dataset\IsolatedTrain\112\2
# dataset\IsolatedTrain\112
# dataset\IsolatedTrain\113
# dataset\IsolatedTrain\114
# dataset\IsolatedTrain\115
# dataset\IsolatedTrain\116
# dataset\IsolatedTrain\117
# dataset\IsolatedTrain\118
# dataset\IsolatedTrain\119
# dataset\IsolatedTrain\12\1
# dataset\IsolatedTrain\12\2
# dataset\IsolatedTrain\12
# dataset\IsolatedTrain\120
# dataset\IsolatedTrain\121
# dataset\IsolatedTrain\122
# dataset\IsolatedTrain\123
# dataset\IsolatedTrain\124
# ...
